# %%
import os
import sys
import pybindgen
from pybindgen import FileCodeSink
from pybindgen.gccxmlparser import ModuleParser

# %%
def module_gen():
    os.chdir('/home/trevorsweetnam/Dropbox/notebooks/eef/emxarr/codegen/dll/emx_test')
    #module_parser = ModuleParser('emx_test_emxAPI', '::')
    #module = module_parser.parse(['emx_test_emxAPI.h'])
    #module.add_include('"emx_test_emxAPI.h"')
    
    module_parser = ModuleParser('emx_test', '::')
    module = module_parser.parse(['emx_test.h'])
    module.add_include('"rt_noninfite.h"')
    module.add_include('"emx_test_emxutil.h"')
    
    pybindgen.write_preamble(FileCodeSink(sys.stdout))
    module.generate(FileCodeSink(sys.stdout))

# %%
module_gen()
# Out:
# INFO Parsing source file "emx_test.h" ...
# INFO gccxml cmd: /usr/bin/gccxml  -I"."   "emx_test.h" -fxml="/tmp/tmpCqcGhP.xml"
# INFO GCCXML version - 0.9
# /* This file was generated by PyBindGen 0.17.0 */
# #define PY_SSIZE_T_CLEAN
# #include <Python.h>
# #include <stddef.h>
#
#
# #if PY_VERSION_HEX < 0x020400F0
#
# #define PyEval_ThreadsInitialized() 1
#
# #define Py_CLEAR(op)				\
#         do {                            	\
#                 if (op) {			\
#                         PyObject *tmp = (PyObject *)(op);	\
#                         (op) = NULL;		\
#                         Py_DECREF(tmp);		\
#                 }				\
#         } while (0)
#
#
# #define Py_VISIT(op)							\
#         do { 								\
#                 if (op) {						\
#                         int vret = visit((PyObject *)(op), arg);	\
#                         if (vret)					\
#                                 return vret;				\
#                 }							\
#         } while (0)
#
# #endif
#
#
#
# #if PY_VERSION_HEX < 0x020500F0
#
# typedef int Py_ssize_t;
# # define PY_SSIZE_T_MAX INT_MAX
# # define PY_SSIZE_T_MIN INT_MIN
# typedef inquiry lenfunc;
# typedef intargfunc ssizeargfunc;
# typedef intobjargproc ssizeobjargproc;
#
# #endif
#
#
# #ifndef PyVarObject_HEAD_INIT
# #define PyVarObject_HEAD_INIT(type, size) \
#         PyObject_HEAD_INIT(type) size,
# #endif
#
#
# #if PY_VERSION_HEX >= 0x03000000
# typedef void* cmpfunc;
# #define PyCObject_FromVoidPtr(a, b) PyCapsule_New(a, NULL, b)
# #define PyCObject_AsVoidPtr(a) PyCapsule_GetPointer(a, NULL)
# #define PyString_FromString(a) PyBytes_FromString(a)
# #define Py_TPFLAGS_CHECKTYPES 0 /* this flag doesn't exist in python 3 */
# #endif
#
#
# #if     __GNUC__ > 2
# # define PYBINDGEN_UNUSED(param) param __attribute__((__unused__))
# #elif     __GNUC__ > 2 || (__GNUC__ == 2 && __GNUC_MINOR__ > 4)
# # define PYBINDGEN_UNUSED(param) __attribute__((__unused__)) param
# #else
# # define PYBINDGEN_UNUSED(param) param
# #endif  /* !__GNUC__ */
#
# #ifndef _PyBindGenWrapperFlags_defined_
# #define _PyBindGenWrapperFlags_defined_
# typedef enum _PyBindGenWrapperFlags {
#    PYBINDGEN_WRAPPER_FLAG_NONE = 0,
#    PYBINDGEN_WRAPPER_FLAG_OBJECT_NOT_OWNED = (1<<0),
# } PyBindGenWrapperFlags;
# #endif
#
#
# /* This file was generated by PyBindGen 0.17.0 */
# #define PY_SSIZE_T_CLEAN
# #include <Python.h>
# #include <stddef.h>
#
#
# #if PY_VERSION_HEX < 0x020400F0
#
# #define PyEval_ThreadsInitialized() 1
#
# #define Py_CLEAR(op)				\
#         do {                            	\
#                 if (op) {			\
#                         PyObject *tmp = (PyObject *)(op);	\
#                         (op) = NULL;		\
#                         Py_DECREF(tmp);		\
#                 }				\
#         } while (0)
#
#
# #define Py_VISIT(op)							\
#         do { 								\
#                 if (op) {						\
#                         int vret = visit((PyObject *)(op), arg);	\
#                         if (vret)					\
#                                 return vret;				\
#                 }							\
#         } while (0)
#
# #endif
#
#
#
# #if PY_VERSION_HEX < 0x020500F0
#
# typedef int Py_ssize_t;
# # define PY_SSIZE_T_MAX INT_MAX
# # define PY_SSIZE_T_MIN INT_MIN
# typedef inquiry lenfunc;
# typedef intargfunc ssizeargfunc;
# typedef intobjargproc ssizeobjargproc;
#
# #endif
#
#
# #ifndef PyVarObject_HEAD_INIT
# #define PyVarObject_HEAD_INIT(type, size) \
#         PyObject_HEAD_INIT(type) size,
# #endif
#
#
# #if PY_VERSION_HEX >= 0x03000000
# typedef void* cmpfunc;
# #define PyCObject_FromVoidPtr(a, b) PyCapsule_New(a, NULL, b)
# #define PyCObject_AsVoidPtr(a) PyCapsule_GetPointer(a, NULL)
# #define PyString_FromString(a) PyBytes_FromString(a)
# #define Py_TPFLAGS_CHECKTYPES 0 /* this flag doesn't exist in python 3 */
# #endif
#
#
# #if     __GNUC__ > 2
# # define PYBINDGEN_UNUSED(param) param __attribute__((__unused__))
# #elif     __GNUC__ > 2 || (__GNUC__ == 2 && __GNUC_MINOR__ > 4)
# # define PYBINDGEN_UNUSED(param) __attribute__((__unused__)) param
# #else
# # define PYBINDGEN_UNUSED(param) param
# #endif  /* !__GNUC__ */
#
# #ifndef _PyBindGenWrapperFlags_defined_
# #define _PyBindGenWrapperFlags_defined_
# typedef enum _PyBindGenWrapperFlags {
#    PYBINDGEN_WRAPPER_FLAG_NONE = 0,
#    PYBINDGEN_WRAPPER_FLAG_OBJECT_NOT_OWNED = (1<<0),
# } PyBindGenWrapperFlags;
# #endif
#
#
# #include "rt_noninfite.h"
# #include "emx_test_emxutil.h"
# static PyMethodDef emx_test_std_functions[] = {
#     {NULL, NULL, 0, NULL}
# };
# #if PY_VERSION_HEX >= 0x03000000
# static struct PyModuleDef std_moduledef = {
#     PyModuleDef_HEAD_INIT,
#     "emx_test.std",
#     NULL,
#     -1,
#     emx_test_std_functions,
# };
# #endif
#
# static PyObject *
# initemx_test_std(void)
# {
#     PyObject *m;
#     #if PY_VERSION_HEX >= 0x03000000
#     m = PyModule_Create(&std_moduledef);
#     #else
#     m = Py_InitModule3((char *) "emx_test.std", emx_test_std_functions, NULL);
#     #endif
#     if (m == NULL) {
#         return NULL;
#     }
#     return m;
# }
# static PyMethodDef emx_test_functions[] = {
#     {NULL, NULL, 0, NULL}
# };
# #if PY_VERSION_HEX >= 0x03000000
# static struct PyModuleDef emx_test_moduledef = {
#     PyModuleDef_HEAD_INIT,
#     "emx_test",
#     NULL,
#     -1,
#     emx_test_functions,
# };
# #endif
#
#
# #if PY_VERSION_HEX >= 0x03000000
#     #define MOD_ERROR NULL
#     #define MOD_INIT(name) PyObject* PyInit_##name(void)
#     #define MOD_RETURN(val) val
# #else
#     #define MOD_ERROR
#     #define MOD_INIT(name) void init##name(void)
#     #define MOD_RETURN(val)
# #endif
# #if defined(__cplusplus)
# extern "C"
# #endif
# #if defined(__GNUC__) && __GNUC__ >= 4
# __attribute__ ((visibility("default")))
# #endif
#
#
# MOD_INIT(emx_test)
# {
#     PyObject *m;
#     PyObject *submodule;
#     #if PY_VERSION_HEX >= 0x03000000
#     m = PyModule_Create(&emx_test_moduledef);
#     #else
#     m = Py_InitModule3((char *) "emx_test", emx_test_functions, NULL);
#     #endif
#     if (m == NULL) {
#         return MOD_ERROR;
#     }
#     submodule = initemx_test_std();
#     if (submodule == NULL) {
#         return MOD_ERROR;
#     }
#     Py_INCREF(submodule);
#     PyModule_AddObject(m, (char *) "std", submodule);
#     return MOD_RETURN(m);
# }
# /home/trevorsweetnam/Dropbox/notebooks/eef/emxarr/codegen/dll/emx_test/emx_test.h:25: WrapperWarning: Parameter '::emxArray_real_T const * in' error (used in extern void emx_test(emxArray_real_T const * in, emxArray_real_T * res) [free function]): TypeLookupError(['emxArray_real_T *'],)
#   extern void emx_test(const emxArray_real_T *in, emxArray_real_T *res);
# /home/trevorsweetnam/Dropbox/notebooks/eef/emxarr/codegen/dll/emx_test/emx_test.h:25: WrapperWarning: Parameter '::emxArray_real_T * res' error (used in extern void emx_test(emxArray_real_T const * in, emxArray_real_T * res) [free function]): TypeLookupError(['emxArray_real_T *'],)
#   extern void emx_test(const emxArray_real_T *in, emxArray_real_T *res);

# %%
cd /home/trevors/Dropbox/notebooks/eef/c/
# Out:
# /home/trevors/Dropbox/notebooks/eef/c

# %%
ls
# Out:
# abs.c                    Message.h                      Optimiser_external.c
# abs.h                    mldivide.c                     Optimiser_external.h
# any.c                    mldivide.h                     Optimiser.h
# any.h                    MultMxPrimeDMx.c               Optimiser_house_wet.c
# bsxfun.c                 MultMxPrimeDMx.h               Optimiser_house_wet.h
# bsxfun.h                 norm.c                         power.c
# colon.c                  norm.h                         power.h
# colon.h                  OptimEnergyAlgos_data.c        PrimalDual_Quad_wet_NonLinearHeater.c
# diag.c                   OptimEnergyAlgos_data.h        PrimalDual_Quad_wet_NonLinearHeater.h
# diag.h                   OptimEnergyAlgos_emxAPI.c      rdivide.c
# expm.c                   OptimEnergyAlgos_emxAPI.h      rdivide.h
# expm.h                   OptimEnergyAlgos_emxutil.c     rtGetInf.c
# eye.c                    OptimEnergyAlgos_emxutil.h     rtGetInf.h
# eye.h                    OptimEnergyAlgos_initialize.c  rtGetNaN.c
# GetOutput.c              OptimEnergyAlgos_initialize.h  rtGetNaN.h
# GetOutput.h              OptimEnergyAlgos_rtwutil.c     rt_nonfinite.c
# GroundTemp.c             OptimEnergyAlgos_rtwutil.h     rt_nonfinite.h
# GroundTemp.h             OptimEnergyAlgos.so*           rtwtypes.h
# HeatSource.c             OptimEnergyAlgos_terminate.c   RunOptim.c
# HeatSource.h             OptimEnergyAlgos_terminate.h   RunOptim.h
# inv.c                    OptimEnergyAlgos_types.h       SetInput.c
# inv.h                    OptimHandler.c                 SetInput.h
# libOptimEnergyAlgos.so*  OptimHandler.h                 sum.c
# log.c                    OptimInterface.c               sum.h
# log.h                    OptimInterface.h
# Message.c                Optimiser.c
